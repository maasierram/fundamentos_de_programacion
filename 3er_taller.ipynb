# %% [markdown]
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.

# %%
edad_empleado = int(input("Digite la edad del empleado: "))
sueldo_basico = float(input("Digite el sueldo basico del mes: "))
bono = round((sueldo_basico) * 0.05, 2)
sueldo_total = sueldo_basico + bono

if edad_empleado >= 55:
  resultado = "Cumple para bonificacion"
  print("La edad del empleado es: {}, el bono sera de: ${:,.0f} {} y su sueldo total es: ${:,.0f}".format(edad_empleado, bono, resultado, sueldo_total))
else:
  resultado = "No cumple para bonificacion"
  print("la edad del empleado es: {}, {}".format(edad_empleado, resultado))
# Out:
# Digite la edad del empleado: 49
# Digite el sueldo basico del mes: 2500000
# la edad del empleado es: 49, No cumple para bonificacion

# %% [markdown]
# Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre

# %%
EC = input("Estado civil del empleado: ")
#Tiene_hijos = input("Tiene usted hijos: ")
Estado_civil = "casado"
#Hijos = "yes"

if EC == Estado_civil:
  print("Aplica para viaje")
else:
  print("No aplica para viaje")
# Out:
# Estado civil del empleado: casado
# Aplica para viaje

# %% [markdown]
# Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.

# %%
sueldo = float(input("Digite el número: "))
comision_1 = round(sueldo * 0.02, 2)
comision_2 = round(sueldo * 0.05, 2)
sueldo_total1 = sueldo + comision_1
sueldo_total2 = sueldo + comision_2

if sueldo > 2000000:
  print("No aplica comision") 
elif sueldo >= 1500001 :
  print("Aplica comision del 5% y su sueldo sera de: ${:,.0f}".format(sueldo_total2)) 
elif sueldo >= 1000000:
  print("Aplica comision del 2% y su sueldo sera de: ${:,.0f}".format(sueldo_total1))
# Out:
# Digite el número: 2120000
# No aplica comision

# %% [markdown]
# Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %%
sueldo = float(input("Digite el salario: "))
dias = int(input("¿Cunatos dias del mes a trabajado?: "))

if sueldo <= 1000000 and dias > 20:
#elif dias > 20:
  resultado = "Se aprueba bono alimentario"
  print("El salario es: ${:,.0f} y los dias trabajados son {}".format(sueldo, dias)) 
  print("Entonces: ",format(resultado))
else:
  print("No aplica para bono alimentario")
# Out:
# Digite el salario: 900000
# ¿Cunatos dias del mes a trabajado?: 22
# El salario es: $900,000 y los dias trabajados son 22
# Entonces  Se aprueba bono alimentario
