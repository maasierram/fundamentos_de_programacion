# %% [markdown]
# Es integrar Ciclos y Funciones en el código del Taller 1 y Taller 2

# %%
def validar(informacion):
  if informacion == "mario, 34, 3142916851, empleado, si":
    print("Los dos ingresados son correcctos, eres Mario")
  else:
    print("Datos incorrectos")

resp = "si"
while resp == "si":
  datos = input("Digite los siguientes datos para validar la autenticidad siguiendo este orden con comas nombre completo, edad, telefono, ocupacion, tiene hijos: ")
  validar(datos)
  resp = input("¿Desea validar otros datos (si/no?) "). lower()
# Out:
# Digite los siguientes datos para validar la autenticidad siguiendo este orden con comas nombre completo, edad, telefono, ocupacion, tiene hijos: mario, 34, 3142916851, empleado, si
# Los dos ingresados son correcctos, eres Mario
# ¿Desea validar otros datos (si/no?) SI
# Digite los siguientes datos para validar la autenticidad siguiendo este orden con comas nombre completo, edad, telefono, ocupacion, tiene hijos: mario, 34, 3142916850, empleado, si
# Datos incorrectos
# ¿Desea validar otros datos (si/no?) NO

# %%
def validar(compra):
  if compra > 1000000:
    
    descuento = round((compra) * 0.15, 2)
    compra_total = compra - descuento
    print("\nDESCUENTO APLICADO por su compra= ${:,.2f}".format(descuento))
    print("\nLa compra total del usuario es = ${:,.2f}".format(compra_total))
 
  else:
    print("\nLa compra es ${:,.0f}, NO APLICA DESCUENTO".format(compra))

resp = "si"
while resp == "si":
  dato = float(input("Digite el valor de la compra: "))
  validar(dato)
  resp = input("¿Desea validar otro valor por concepto de compra (si/no)?: ")
# Out:
# Digite el valor de la compra: 1300000
#
# DESCUENTO APLICADO por su compra= $195,000.00
#
# La compra total del usuario es = $1,105,000.00
# ¿Desea validar otro valor por concepto de compra (si/no)?: si
# Digite el valor de la compra: 800000
#
# La compra es $800,000, NO APLICA DESCUENTO
