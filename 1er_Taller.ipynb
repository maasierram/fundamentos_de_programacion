# %%
csz
sd#No de Identificación, Nombres, Apellidos, Dirección, Teléfono, Edad, Estado Civil, Número de hijos, Estatura en centímetros, fecha de contratación (Día/mes/año), Sueldo básico, Días Laborados.

No_Identificacion = input("Digite el numero de identificacion: ")
Nombres = input("Digite sus nombres: ")
Apellidos = input("Digite sus Apellidos: ")
Direccion_de_residencia = input("Escriba la direccion: ")
Numero_de_telefono = input("Escriba el numero de telefono: ")
Edad = input("Escriba su edad (solo numeros): ")
Estado_Civil = input("Escriba su estado: ")
Hijos = input("Digite numero de hijos: ")
Estatura = input("Digite su estatura (cm): ")
Fecha_de_contratacion = input("Digite la fecha exacta (Día/mes/año): ")
Sueldo_basico = input("Digite el valor del salario: ")
Dias_laborados = input("Escriba el numero de dias laborados: ")
print(No_Identificacion);print(Nombres);print(Apellidos);print(Direccion_de_residencia);print(Numero_de_telefono);print(Edad);print(Estado_Civil);print(Hijos);print(Estatura);print(Fecha_de_contratacion);print(Sueldo_basico);print(Dias_laborados)
# Out:
# Digite el numero de identificacion: 12233
# Digite sus nombres: sddsfs
# Digite sus Apellidos: sfsfs
# Escriba la direccion: fsafsfsfs
# Escriba el numero de telefono: dzsa
# Escriba su edad (solo numeros): sfsfsfsf
# Escriba su estado: dsdfd
# Digite numero de hijos: sdfsd
# Digite su estatura (cm): ghgjghj
# Digite la fecha exacta (Día/mes/año): fthfft
# Digite el valor del salario: dgdgt
# Escriba el numero de dias laborados: rrtteter
# 12233
# sddsfs
# sfsfs
# fsafsfsfs
# dzsa
# sfsfsfsf
# dsdfd
# sdfsd
# ghgjghj
# fthfft
# dgdgt
# rrtteter
