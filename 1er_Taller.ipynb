# %%
#No de Identificación, Nombres, Apellidos, Dirección, Teléfono, Edad, Estado Civil, Número de hijos, Estatura en centímetros, fecha de contratación (Día/mes/año), Sueldo básico, Días Laborados.

No_Identificacion = input("Digite el numero de identificacion: ")
Nombres = input("Digite sus nombres: ")
Apellidos = input("Digite sus Apellidos: ")
Direccion_de_residencia = input("Escriba la direccion: ")
Numero_de_telefono = input("Escriba el numero de telefono: ")
Edad = input("Escriba su edad (solo numeros): ")
Estado_Civil = input("Escriba su estado: ")
Hijos = input("Digite numero de hijos: ")
Estatura = input("Digite su estatura (cm): ")
Fecha_de_contratacion = input("Digite la fecha exacta (Día/mes/año): ")
Sueldo_basico = input("Digite el valor del salario: ")
Dias_laborados = input("Escriba el numero de dias laborados: ")
print("su ID es {}, sus nombres son {} y sus apellidos son {}. la direccion de residencia es {} y su numero de telefono es {}. Su edad es {}, su estado civil es {}. Cuantos hijos tiene {}, su estatura es {}, cual es la fecha de contratacion {}, cuanto es su sueldo basico {}, cuantos dias labora {}".format(No_Identificacion, Nombres, Apellidos, Direccion_de_residencia, Numero_de_telefono, Edad, Estado_Civil, Hijos, Estatura, Fecha_de_contratacion, Sueldo_basico, Dias_laborados ))
# Out:
# Digite el numero de identificacion: 232345
# Digite sus nombres: MARIO
# Digite sus Apellidos: SIERRA
# Escriba la direccion: CALLE 58
# Escriba el numero de telefono: 314291
# Escriba su edad (solo numeros): 34
# Escriba su estado: UNION
# Digite numero de hijos: 1
# Digite su estatura (cm): 1.80
# Digite la fecha exacta (Día/mes/año): 04/06/2020
# Digite el valor del salario: 2200000
# Escriba el numero de dias laborados: 6
# su ID es 232345, sus nombres son MARIO y sus apellidos son SIERRA. la direccion de residencia es CALLE 58 y su numero de telefono es 314291. Su edad es 34, su estado civil es UNION. Cuantos hijos tiene 1, su estatura es 1.80, cual es la fecha de contratacion 04/06/2020, cuanto es su sueldo basico 2200000, cuantos dias labora 6
